# %% [markdown]
# ### Imports

# %%
import pandas as pd
from pandas_datareader import data
from datetime import datetime
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ### Obtain and Prepare Data

# %%
start = datetime.strptime('2020-01-02','%Y-%m-%d')
end = datetime.strptime('2022-02-28','%Y-%m-%d')

df = data.DataReader('EURUSD=X',start=start, end=end, data_source='yahoo')
df = df[:1500]['Close']

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
data = scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
training_size=int(len(data)*0.65)
test_size=len(data)-training_size
train_data,test_data=data[0:training_size,:],data[training_size:len(data),:]

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i+time_step,0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1],1)

# %% [markdown]
# ### Build and Train LSTM

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential() 
model.add(LSTM(50,return_sequences=True,input_shape=(time_step,1))) 
model.add(LSTM(50,return_sequences=True)) 
model.add(LSTM(50)) 
model.add(Dense(1)) 
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
start= time.time()
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)
end=time.time()
# Out:
# Epoch 1/100
# 5/5 [==============================] - 9s 540ms/step - loss: 0.3890 - val_loss: 0.0184
# Epoch 2/100
# 5/5 [==============================] - 1s 144ms/step - loss: 0.0486 - val_loss: 0.0907
# Epoch 3/100
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0271 - val_loss: 0.0034
# Epoch 4/100
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0265 - val_loss: 0.0040
# Epoch 5/100
# 5/5 [==============================] - 1s 142ms/step - loss: 0.0113 - val_loss: 0.0309
# Epoch 6/100
# 5/5 [==============================] - 1s 154ms/step - loss: 0.0115 - val_loss: 0.0384
# Epoch 7/100
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0076 - val_loss: 0.0145
# Epoch 8/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0069 - val_loss: 0.0136
# Epoch 9/100
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0062 - val_loss: 0.0211
# Epoch 10/100
# 5/5 [==============================] - 1s 144ms/step - loss: 0.0057 - val_loss: 0.0243
# Epoch 11/100
# 5/5 [==============================] - 1s 141ms/step - loss: 0.0056 - val_loss: 0.0177
# Epoch 12/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0056 - val_loss: 0.0144
# Epoch 13/100
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0053 - val_loss: 0.0187
# Epoch 14/100
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0053 - val_loss: 0.0186
# Epoch 15/100
# 5/5 [==============================] - 1s 143ms/step - loss: 0.0050 - val_loss: 0.0143
# Epoch 16/100
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0049 - val_loss: 0.0149
# Epoch 17/100
# 5/5 [==============================] - 1s 142ms/step - loss: 0.0048 - val_loss: 0.0137
# Epoch 18/100
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0047 - val_loss: 0.0152
# Epoch 19/100
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0047 - val_loss: 0.0137
# Epoch 20/100
# 5/5 [==============================] - 1s 139ms/step - loss: 0.0046 - val_loss: 0.0123
# Epoch 21/100
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0046 - val_loss: 0.0135
# Epoch 22/100
# 5/5 [==============================] - 1s 151ms/step - loss: 0.0045 - val_loss: 0.0119
# Epoch 23/100
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0045 - val_loss: 0.0135
# Epoch 24/100
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0046 - val_loss: 0.0125
# Epoch 25/100
# 5/5 [==============================] - 1s 158ms/step - loss: 0.0044 - val_loss: 0.0106
# Epoch 26/100
# 5/5 [==============================] - 1s 152ms/step - loss: 0.0044 - val_loss: 0.0117
# Epoch 27/100
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0044 - val_loss: 0.0114
# Epoch 28/100
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0044 - val_loss: 0.0100
# Epoch 29/100
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0045 - val_loss: 0.0124
# Epoch 30/100
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0043 - val_loss: 0.0109
# Epoch 31/100
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0042 - val_loss: 0.0105
# Epoch 32/100
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0042 - val_loss: 0.0114
# Epoch 33/100
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0042 - val_loss: 0.0106
# Epoch 34/100
# 5/5 [==============================] - 1s 156ms/step - loss: 0.0041 - val_loss: 0.0104
# Epoch 35/100
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0041 - val_loss: 0.0105
# Epoch 36/100
# 5/5 [==============================] - 1s 158ms/step - loss: 0.0041 - val_loss: 0.0107
# Epoch 37/100
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0042 - val_loss: 0.0106
# Epoch 38/100
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0040 - val_loss: 0.0088
# Epoch 39/100
# 5/5 [==============================] - 1s 196ms/step - loss: 0.0040 - val_loss: 0.0092
# Epoch 40/100
# 5/5 [==============================] - 1s 160ms/step - loss: 0.0041 - val_loss: 0.0082
# Epoch 41/100
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0039 - val_loss: 0.0107
# Epoch 42/100
# 5/5 [==============================] - 1s 154ms/step - loss: 0.0040 - val_loss: 0.0081
# Epoch 43/100
# 5/5 [==============================] - 1s 140ms/step - loss: 0.0039 - val_loss: 0.0094
# Epoch 44/100
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0039 - val_loss: 0.0082
# Epoch 45/100
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0038 - val_loss: 0.0077
# Epoch 46/100
# 5/5 [==============================] - 1s 151ms/step - loss: 0.0037 - val_loss: 0.0085
# Epoch 47/100
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0037 - val_loss: 0.0072
# Epoch 48/100
# 5/5 [==============================] - 1s 152ms/step - loss: 0.0037 - val_loss: 0.0081
# Epoch 49/100
# 5/5 [==============================] - 1s 151ms/step - loss: 0.0036 - val_loss: 0.0072
# Epoch 50/100
# 5/5 [==============================] - 1s 155ms/step - loss: 0.0035 - val_loss: 0.0086
# Epoch 51/100
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0035 - val_loss: 0.0065
# Epoch 52/100
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0034 - val_loss: 0.0079
# Epoch 53/100
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0034 - val_loss: 0.0064
# Epoch 54/100
# 5/5 [==============================] - 1s 143ms/step - loss: 0.0033 - val_loss: 0.0073
# Epoch 55/100
# 5/5 [==============================] - 1s 152ms/step - loss: 0.0032 - val_loss: 0.0085
# Epoch 56/100
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0035 - val_loss: 0.0047
# Epoch 57/100
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0039 - val_loss: 0.0080
# Epoch 58/100
# 5/5 [==============================] - 1s 141ms/step - loss: 0.0038 - val_loss: 0.0088
# Epoch 59/100
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0035 - val_loss: 0.0055
# Epoch 60/100
# 5/5 [==============================] - 1s 154ms/step - loss: 0.0035 - val_loss: 0.0084
# Epoch 61/100
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0032 - val_loss: 0.0065
# Epoch 62/100
# 5/5 [==============================] - 1s 154ms/step - loss: 0.0031 - val_loss: 0.0067
# Epoch 63/100
# 5/5 [==============================] - 1s 143ms/step - loss: 0.0031 - val_loss: 0.0063
# Epoch 64/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0030 - val_loss: 0.0062
# Epoch 65/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0031 - val_loss: 0.0045
# Epoch 66/100
# 5/5 [==============================] - 1s 159ms/step - loss: 0.0032 - val_loss: 0.0078
# Epoch 67/100
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0031 - val_loss: 0.0042
# Epoch 68/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0033 - val_loss: 0.0075
# Epoch 69/100
# 5/5 [==============================] - 1s 154ms/step - loss: 0.0029 - val_loss: 0.0061
# Epoch 70/100
# 5/5 [==============================] - 1s 148ms/step - loss: 0.0031 - val_loss: 0.0046
# Epoch 71/100
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0033 - val_loss: 0.0081
# Epoch 72/100
# 5/5 [==============================] - 1s 158ms/step - loss: 0.0033 - val_loss: 0.0042
# Epoch 73/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0033 - val_loss: 0.0080
# Epoch 74/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0028 - val_loss: 0.0047
# Epoch 75/100
# 5/5 [==============================] - 1s 225ms/step - loss: 0.0030 - val_loss: 0.0080
# Epoch 76/100
# 5/5 [==============================] - 1s 231ms/step - loss: 0.0028 - val_loss: 0.0051
# Epoch 77/100
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0027 - val_loss: 0.0084
# Epoch 78/100
# 5/5 [==============================] - 1s 157ms/step - loss: 0.0030 - val_loss: 0.0038
# Epoch 79/100
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0032 - val_loss: 0.0073
# Epoch 80/100
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0026 - val_loss: 0.0045
# Epoch 81/100
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0028 - val_loss: 0.0060
# Epoch 82/100
# 5/5 [==============================] - 1s 159ms/step - loss: 0.0028 - val_loss: 0.0058
# Epoch 83/100
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0026 - val_loss: 0.0059
# Epoch 84/100
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0025 - val_loss: 0.0051
# Epoch 85/100
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0025 - val_loss: 0.0065
# Epoch 86/100
# 5/5 [==============================] - 1s 252ms/step - loss: 0.0028 - val_loss: 0.0042
# Epoch 87/100
# 5/5 [==============================] - 1s 238ms/step - loss: 0.0026 - val_loss: 0.0064
# Epoch 88/100
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0024 - val_loss: 0.0040
# Epoch 89/100
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0027 - val_loss: 0.0068
# Epoch 90/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0025 - val_loss: 0.0043
# Epoch 91/100
# 5/5 [==============================] - 1s 143ms/step - loss: 0.0025 - val_loss: 0.0063
# Epoch 92/100
# 5/5 [==============================] - 1s 153ms/step - loss: 0.0025 - val_loss: 0.0044
# Epoch 93/100
# 5/5 [==============================] - 1s 151ms/step - loss: 0.0024 - val_loss: 0.0061
# Epoch 94/100
# 5/5 [==============================] - 1s 142ms/step - loss: 0.0025 - val_loss: 0.0045
# Epoch 95/100
# 5/5 [==============================] - 1s 157ms/step - loss: 0.0024 - val_loss: 0.0060
# Epoch 96/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0024 - val_loss: 0.0050
# Epoch 97/100
# 5/5 [==============================] - 1s 153ms/step - loss: 0.0024 - val_loss: 0.0054
# Epoch 98/100
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0024 - val_loss: 0.0066
# Epoch 99/100
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0027 - val_loss: 0.0036
# Epoch 100/100
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0026 - val_loss: 0.0070

# %% [markdown]
# ### Make Predictions

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %% [markdown]
# ### Visualize Results

# %%
look_back=time_step
trainPredictPlot=np.empty_like(data)
trainPredictPlot[:,:]=np.nan
trainPredictPlot[look_back:len(train_predict)+look_back,:] = train_predict

testPredictPlot=np.empty_like(data)
testPredictPlot[:,:] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(data)-1,:] = test_predict

plt.figure(figsize=(12,8))
plt.plot(scaler.inverse_transform(data))
plt.plot(testPredictPlot)
plt.plot(trainPredictPlot)
plt.legend(['Actual Data','Test Predict','Train Predict'])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,8))
plt.plot(scaler.inverse_transform(data)[len(train_predict)+(look_back*2)+1:len(data)-1])
plt.plot(test_predict)
plt.legend(['Actual Data','Test Predict'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Evaluation

# %%
from sklearn.metrics import mean_squared_error
test_predict=model.predict(X_test)
print('MSE:',mean_squared_error(y_test, test_predict))
# Out:
# MSE: 0.007045719371697432

# %%
print('Coefficient of Variation:',df.std()/df.mean())
# Out:
# Coefficient of Variation: 0.03592553730685507

# %%
print('Time taken for training in seconds:',end-start)
# Out:
# Time taken for training in seconds: 90.48284268379211
