# %% [markdown]
# ### Imports

# %%
import pandas as pd
from pandas_datareader import data
from datetime import datetime
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ### Obtain and Prepare Data

# %%
start = datetime.strptime('2020-01-02','%Y-%m-%d')
end = datetime.strptime('2022-02-28','%Y-%m-%d')

df = data.DataReader('EURUSD=X',start=start, end=end, data_source='yahoo')
df = df[:1500]['Close']

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
data = scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
training_size=int(len(data)*0.65)
test_size=len(data)-training_size
train_data,test_data=data[0:training_size,:],data[training_size:len(data),:]

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i+time_step,0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1],1)

# %% [markdown]
# ### Build and Train LSTM

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential() 
model.add(LSTM(50,return_sequences=True,input_shape=(time_step,1))) 
model.add(LSTM(50,return_sequences=True)) 
model.add(LSTM(50)) 
model.add(Dense(1)) 
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
start= time.time()
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)
end=time.time()
# Out:
# Epoch 1/100
# 5/5 [==============================] - 5s 297ms/step - loss: 0.3122 - val_loss: 0.0043
# Epoch 2/100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0426 - val_loss: 0.0516
# Epoch 3/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0117 - val_loss: 0.0031
# Epoch 4/100
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0250 - val_loss: 0.0124
# Epoch 5/100
# 5/5 [==============================] - 1s 109ms/step - loss: 0.0073 - val_loss: 0.0517
# Epoch 6/100
# 5/5 [==============================] - 1s 115ms/step - loss: 0.0123 - val_loss: 0.0278
# Epoch 7/100
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0066 - val_loss: 0.0119
# Epoch 8/100
# 5/5 [==============================] - 0s 102ms/step - loss: 0.0084 - val_loss: 0.0199
# Epoch 9/100
# 5/5 [==============================] - 1s 115ms/step - loss: 0.0063 - val_loss: 0.0344
# Epoch 10/100
# 5/5 [==============================] - 1s 118ms/step - loss: 0.0068 - val_loss: 0.0202
# Epoch 11/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.0060 - val_loss: 0.0147
# Epoch 12/100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0058 - val_loss: 0.0216
# Epoch 13/100
# 5/5 [==============================] - 1s 113ms/step - loss: 0.0056 - val_loss: 0.0235
# Epoch 14/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0054 - val_loss: 0.0166
# Epoch 15/100
# 5/5 [==============================] - 1s 121ms/step - loss: 0.0052 - val_loss: 0.0172
# Epoch 16/100
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0051 - val_loss: 0.0200
# Epoch 17/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0051 - val_loss: 0.0155
# Epoch 18/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0049 - val_loss: 0.0154
# Epoch 19/100
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0048 - val_loss: 0.0154
# Epoch 20/100
# 5/5 [==============================] - 1s 117ms/step - loss: 0.0048 - val_loss: 0.0141
# Epoch 21/100
# 5/5 [==============================] - 1s 116ms/step - loss: 0.0049 - val_loss: 0.0133
# Epoch 22/100
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0049 - val_loss: 0.0169
# Epoch 23/100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0048 - val_loss: 0.0121
# Epoch 24/100
# 5/5 [==============================] - 0s 102ms/step - loss: 0.0047 - val_loss: 0.0130
# Epoch 25/100
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0046 - val_loss: 0.0120
# Epoch 26/100
# 5/5 [==============================] - 1s 116ms/step - loss: 0.0046 - val_loss: 0.0127
# Epoch 27/100
# 5/5 [==============================] - 1s 119ms/step - loss: 0.0045 - val_loss: 0.0139
# Epoch 28/100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0046 - val_loss: 0.0127
# Epoch 29/100
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0045 - val_loss: 0.0102
# Epoch 30/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0045 - val_loss: 0.0121
# Epoch 31/100
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0044 - val_loss: 0.0111
# Epoch 32/100
# 5/5 [==============================] - 1s 110ms/step - loss: 0.0043 - val_loss: 0.0112
# Epoch 33/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0042 - val_loss: 0.0111
# Epoch 34/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.0041 - val_loss: 0.0102
# Epoch 35/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0043 - val_loss: 0.0107
# Epoch 36/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0043 - val_loss: 0.0102
# Epoch 37/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0040 - val_loss: 0.0112
# Epoch 38/100
# 5/5 [==============================] - 1s 110ms/step - loss: 0.0038 - val_loss: 0.0099
# Epoch 39/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0038 - val_loss: 0.0103
# Epoch 40/100
# 5/5 [==============================] - 1s 112ms/step - loss: 0.0036 - val_loss: 0.0078
# Epoch 41/100
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0037 - val_loss: 0.0114
# Epoch 42/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0042 - val_loss: 0.0053
# Epoch 43/100
# 5/5 [==============================] - 1s 110ms/step - loss: 0.0048 - val_loss: 0.0146
# Epoch 44/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0044 - val_loss: 0.0063
# Epoch 45/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.0041 - val_loss: 0.0107
# Epoch 46/100
# 5/5 [==============================] - 1s 119ms/step - loss: 0.0035 - val_loss: 0.0089
# Epoch 47/100
# 5/5 [==============================] - 1s 110ms/step - loss: 0.0035 - val_loss: 0.0099
# Epoch 48/100
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0033 - val_loss: 0.0083
# Epoch 49/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0031 - val_loss: 0.0102
# Epoch 50/100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0032 - val_loss: 0.0084
# Epoch 51/100
# 5/5 [==============================] - 1s 112ms/step - loss: 0.0032 - val_loss: 0.0067
# Epoch 52/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0033 - val_loss: 0.0094
# Epoch 53/100
# 5/5 [==============================] - 1s 109ms/step - loss: 0.0030 - val_loss: 0.0065
# Epoch 54/100
# 5/5 [==============================] - 1s 110ms/step - loss: 0.0029 - val_loss: 0.0091
# Epoch 55/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.0031 - val_loss: 0.0052
# Epoch 56/100
# 5/5 [==============================] - 1s 109ms/step - loss: 0.0032 - val_loss: 0.0092
# Epoch 57/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0030 - val_loss: 0.0054
# Epoch 58/100
# 5/5 [==============================] - 1s 112ms/step - loss: 0.0030 - val_loss: 0.0096
# Epoch 59/100
# 5/5 [==============================] - 1s 112ms/step - loss: 0.0030 - val_loss: 0.0070
# Epoch 60/100
# 5/5 [==============================] - 1s 110ms/step - loss: 0.0029 - val_loss: 0.0068
# Epoch 61/100
# 5/5 [==============================] - 1s 109ms/step - loss: 0.0029 - val_loss: 0.0085
# Epoch 62/100
# 5/5 [==============================] - 1s 133ms/step - loss: 0.0027 - val_loss: 0.0058
# Epoch 63/100
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0029 - val_loss: 0.0097
# Epoch 64/100
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0029 - val_loss: 0.0054
# Epoch 65/100
# 5/5 [==============================] - 1s 123ms/step - loss: 0.0031 - val_loss: 0.0110
# Epoch 66/100
# 5/5 [==============================] - 1s 117ms/step - loss: 0.0033 - val_loss: 0.0062
# Epoch 67/100
# 5/5 [==============================] - 1s 120ms/step - loss: 0.0029 - val_loss: 0.0093
# Epoch 68/100
# 5/5 [==============================] - 1s 120ms/step - loss: 0.0027 - val_loss: 0.0080
# Epoch 69/100
# 5/5 [==============================] - 1s 115ms/step - loss: 0.0028 - val_loss: 0.0068
# Epoch 70/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0027 - val_loss: 0.0082
# Epoch 71/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0026 - val_loss: 0.0056
# Epoch 72/100
# 5/5 [==============================] - 1s 109ms/step - loss: 0.0027 - val_loss: 0.0064
# Epoch 73/100
# 5/5 [==============================] - 0s 103ms/step - loss: 0.0027 - val_loss: 0.0073
# Epoch 74/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0026 - val_loss: 0.0060
# Epoch 75/100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0026 - val_loss: 0.0078
# Epoch 76/100
# 5/5 [==============================] - 1s 109ms/step - loss: 0.0025 - val_loss: 0.0070
# Epoch 77/100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0025 - val_loss: 0.0060
# Epoch 78/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.0027 - val_loss: 0.0081
# Epoch 79/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0025 - val_loss: 0.0052
# Epoch 80/100
# 5/5 [==============================] - 1s 109ms/step - loss: 0.0027 - val_loss: 0.0104
# Epoch 81/100
# 5/5 [==============================] - 1s 117ms/step - loss: 0.0031 - val_loss: 0.0047
# Epoch 82/100
# 5/5 [==============================] - 1s 124ms/step - loss: 0.0027 - val_loss: 0.0096
# Epoch 83/100
# 5/5 [==============================] - 1s 120ms/step - loss: 0.0026 - val_loss: 0.0067
# Epoch 84/100
# 5/5 [==============================] - 1s 117ms/step - loss: 0.0026 - val_loss: 0.0068
# Epoch 85/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0024 - val_loss: 0.0083
# Epoch 86/100
# 5/5 [==============================] - 1s 120ms/step - loss: 0.0024 - val_loss: 0.0063
# Epoch 87/100
# 5/5 [==============================] - 1s 118ms/step - loss: 0.0025 - val_loss: 0.0070
# Epoch 88/100
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0024 - val_loss: 0.0064
# Epoch 89/100
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0023 - val_loss: 0.0056
# Epoch 90/100
# 5/5 [==============================] - 1s 113ms/step - loss: 0.0024 - val_loss: 0.0080
# Epoch 91/100
# 5/5 [==============================] - 1s 110ms/step - loss: 0.0023 - val_loss: 0.0061
# Epoch 92/100
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0024 - val_loss: 0.0104
# Epoch 93/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0025 - val_loss: 0.0061
# Epoch 94/100
# 5/5 [==============================] - 1s 113ms/step - loss: 0.0024 - val_loss: 0.0088
# Epoch 95/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0024 - val_loss: 0.0066
# Epoch 96/100
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0024 - val_loss: 0.0047
# Epoch 97/100
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0025 - val_loss: 0.0103
# Epoch 98/100
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0031 - val_loss: 0.0068
# Epoch 99/100
# 5/5 [==============================] - 1s 115ms/step - loss: 0.0025 - val_loss: 0.0125
# Epoch 100/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0025 - val_loss: 0.0055

# %% [markdown]
# ### Make Predictions

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %% [markdown]
# ### Visualize Results

# %%
look_back=time_step
trainPredictPlot=np.empty_like(data)
trainPredictPlot[:,:]=np.nan
trainPredictPlot[look_back:len(train_predict)+look_back,:] = train_predict

testPredictPlot=np.empty_like(data)
testPredictPlot[:,:] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(data)-1,:] = test_predict

plt.figure(figsize=(12,8))
plt.plot(scaler.inverse_transform(data))
plt.plot(testPredictPlot)
plt.plot(trainPredictPlot)
plt.legend(['Actual Data','Test Predict','Train Predict'])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,8))
plt.plot(scaler.inverse_transform(data)[len(train_predict)+(look_back*2)+1:len(data)-1])
plt.plot(test_predict)
plt.legend(['Actual Data','Test Predict'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Evaluation

# %%
from sklearn.metrics import mean_squared_error
test_predict=model.predict(X_test)
print('MSE:',mean_squared_error(y_test, test_predict))
# Out:
# MSE: 0.005479343722477439

# %%
print('Volatility:',np.log(df/df.shift()).std()*252**0.5)
# Out:
# Volatility: 0.06625288281138839

# %%
print('Time taken for training in seconds:',end-start)
# Out:
# Time taken for training in seconds: 59.25431799888611
