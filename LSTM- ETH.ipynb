# %% [markdown]
# ### Imports

# %%
import pandas as pd
from pandas_datareader import data
from datetime import datetime
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ### Obtain and Prepare Data

# %%
start = datetime.strptime('2020-01-02','%Y-%m-%d')
end = datetime.strptime('2022-02-28','%Y-%m-%d')

df = data.DataReader('ETH-USD',start=start, end=end, data_source='yahoo')
df = df[:1500]['Close']

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
data = scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
training_size=int(len(data)*0.65)
test_size=len(data)-training_size
train_data,test_data=data[0:training_size,:],data[training_size:len(data),:]

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i+time_step,0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1],1)

# %% [markdown]
# ### Build and Train LSTM

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential() 
model.add(LSTM(50,return_sequences=True,input_shape=(time_step,1))) 
model.add(LSTM(50,return_sequences=True)) 
model.add(LSTM(50)) 
model.add(Dense(1)) 
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
start= time.time()
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)
end=time.time()
# Out:
# Epoch 1/100
# 7/7 [==============================] - 5s 248ms/step - loss: 0.0395 - val_loss: 0.0308
# Epoch 2/100
# 7/7 [==============================] - 1s 117ms/step - loss: 0.0106 - val_loss: 0.0383
# Epoch 3/100
# 7/7 [==============================] - 1s 116ms/step - loss: 0.0050 - val_loss: 0.0898
# Epoch 4/100
# 7/7 [==============================] - 1s 110ms/step - loss: 0.0056 - val_loss: 0.0088
# Epoch 5/100
# 7/7 [==============================] - 1s 121ms/step - loss: 0.0041 - val_loss: 0.0106
# Epoch 6/100
# 7/7 [==============================] - 1s 110ms/step - loss: 0.0036 - val_loss: 0.0068
# Epoch 7/100
# 7/7 [==============================] - 1s 114ms/step - loss: 0.0037 - val_loss: 0.0086
# Epoch 8/100
# 7/7 [==============================] - 1s 115ms/step - loss: 0.0038 - val_loss: 0.0077
# Epoch 9/100
# 7/7 [==============================] - 1s 119ms/step - loss: 0.0031 - val_loss: 0.0102
# Epoch 10/100
# 7/7 [==============================] - 1s 114ms/step - loss: 0.0026 - val_loss: 0.0073
# Epoch 11/100
# 7/7 [==============================] - 1s 117ms/step - loss: 0.0028 - val_loss: 0.0105
# Epoch 12/100
# 7/7 [==============================] - 1s 111ms/step - loss: 0.0024 - val_loss: 0.0073
# Epoch 13/100
# 7/7 [==============================] - 1s 114ms/step - loss: 0.0025 - val_loss: 0.0098
# Epoch 14/100
# 7/7 [==============================] - 1s 111ms/step - loss: 0.0024 - val_loss: 0.0085
# Epoch 15/100
# 7/7 [==============================] - 1s 119ms/step - loss: 0.0023 - val_loss: 0.0085
# Epoch 16/100
# 7/7 [==============================] - 1s 113ms/step - loss: 0.0023 - val_loss: 0.0089
# Epoch 17/100
# 7/7 [==============================] - 1s 110ms/step - loss: 0.0022 - val_loss: 0.0104
# Epoch 18/100
# 7/7 [==============================] - 1s 117ms/step - loss: 0.0022 - val_loss: 0.0108
# Epoch 19/100
# 7/7 [==============================] - 1s 113ms/step - loss: 0.0021 - val_loss: 0.0103
# Epoch 20/100
# 7/7 [==============================] - 1s 111ms/step - loss: 0.0021 - val_loss: 0.0134
# Epoch 21/100
# 7/7 [==============================] - 1s 108ms/step - loss: 0.0022 - val_loss: 0.0143
# Epoch 22/100
# 7/7 [==============================] - 1s 119ms/step - loss: 0.0020 - val_loss: 0.0154
# Epoch 23/100
# 7/7 [==============================] - 1s 110ms/step - loss: 0.0019 - val_loss: 0.0120
# Epoch 24/100
# 7/7 [==============================] - 1s 111ms/step - loss: 0.0021 - val_loss: 0.0226
# Epoch 25/100
# 7/7 [==============================] - 1s 113ms/step - loss: 0.0018 - val_loss: 0.0146
# Epoch 26/100
# 7/7 [==============================] - 1s 115ms/step - loss: 0.0017 - val_loss: 0.0170
# Epoch 27/100
# 7/7 [==============================] - 1s 114ms/step - loss: 0.0016 - val_loss: 0.0163
# Epoch 28/100
# 7/7 [==============================] - 1s 110ms/step - loss: 0.0015 - val_loss: 0.0236
# Epoch 29/100
# 7/7 [==============================] - 1s 110ms/step - loss: 0.0014 - val_loss: 0.0121
# Epoch 30/100
# 7/7 [==============================] - 1s 113ms/step - loss: 0.0013 - val_loss: 0.0115
# Epoch 31/100
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0013 - val_loss: 0.0181
# Epoch 32/100
# 7/7 [==============================] - 1s 110ms/step - loss: 0.0014 - val_loss: 0.0066
# Epoch 33/100
# 7/7 [==============================] - 1s 110ms/step - loss: 0.0014 - val_loss: 0.0145
# Epoch 34/100
# 7/7 [==============================] - 1s 111ms/step - loss: 0.0010 - val_loss: 0.0071
# Epoch 35/100
# 7/7 [==============================] - 1s 117ms/step - loss: 9.2319e-04 - val_loss: 0.0080
# Epoch 36/100
# 7/7 [==============================] - 1s 118ms/step - loss: 8.4274e-04 - val_loss: 0.0082
# Epoch 37/100
# 7/7 [==============================] - 1s 108ms/step - loss: 8.0540e-04 - val_loss: 0.0071
# Epoch 38/100
# 7/7 [==============================] - 1s 111ms/step - loss: 6.9634e-04 - val_loss: 0.0090
# Epoch 39/100
# 7/7 [==============================] - 1s 117ms/step - loss: 6.5341e-04 - val_loss: 0.0116
# Epoch 40/100
# 7/7 [==============================] - 1s 111ms/step - loss: 6.4759e-04 - val_loss: 0.0159
# Epoch 41/100
# 7/7 [==============================] - 1s 109ms/step - loss: 5.7059e-04 - val_loss: 0.0152
# Epoch 42/100
# 7/7 [==============================] - 1s 120ms/step - loss: 5.7123e-04 - val_loss: 0.0167
# Epoch 43/100
# 7/7 [==============================] - 1s 114ms/step - loss: 6.0407e-04 - val_loss: 0.0205
# Epoch 44/100
# 7/7 [==============================] - 1s 114ms/step - loss: 5.4915e-04 - val_loss: 0.0188
# Epoch 45/100
# 7/7 [==============================] - 1s 111ms/step - loss: 5.7212e-04 - val_loss: 0.0256
# Epoch 46/100
# 7/7 [==============================] - 1s 111ms/step - loss: 7.4058e-04 - val_loss: 0.0129
# Epoch 47/100
# 7/7 [==============================] - 1s 112ms/step - loss: 5.7092e-04 - val_loss: 0.0173
# Epoch 48/100
# 7/7 [==============================] - 1s 112ms/step - loss: 6.4764e-04 - val_loss: 0.0186
# Epoch 49/100
# 7/7 [==============================] - 1s 120ms/step - loss: 6.7207e-04 - val_loss: 0.0098
# Epoch 50/100
# 7/7 [==============================] - 1s 121ms/step - loss: 6.3024e-04 - val_loss: 0.0105
# Epoch 51/100
# 7/7 [==============================] - 1s 115ms/step - loss: 6.0936e-04 - val_loss: 0.0163
# Epoch 52/100
# 7/7 [==============================] - 1s 111ms/step - loss: 6.3002e-04 - val_loss: 0.0113
# Epoch 53/100
# 7/7 [==============================] - 1s 118ms/step - loss: 6.3824e-04 - val_loss: 0.0100
# Epoch 54/100
# 7/7 [==============================] - 1s 112ms/step - loss: 7.8114e-04 - val_loss: 0.0242
# Epoch 55/100
# 7/7 [==============================] - 1s 110ms/step - loss: 6.7039e-04 - val_loss: 0.0102
# Epoch 56/100
# 7/7 [==============================] - 1s 113ms/step - loss: 6.0218e-04 - val_loss: 0.0102
# Epoch 57/100
# 7/7 [==============================] - 1s 116ms/step - loss: 5.7738e-04 - val_loss: 0.0142
# Epoch 58/100
# 7/7 [==============================] - 1s 115ms/step - loss: 5.5158e-04 - val_loss: 0.0164
# Epoch 59/100
# 7/7 [==============================] - 1s 114ms/step - loss: 5.2062e-04 - val_loss: 0.0119
# Epoch 60/100
# 7/7 [==============================] - 1s 110ms/step - loss: 6.5043e-04 - val_loss: 0.0202
# Epoch 61/100
# 7/7 [==============================] - 1s 121ms/step - loss: 6.5804e-04 - val_loss: 0.0104
# Epoch 62/100
# 7/7 [==============================] - 1s 116ms/step - loss: 5.7118e-04 - val_loss: 0.0140
# Epoch 63/100
# 7/7 [==============================] - 1s 112ms/step - loss: 5.3968e-04 - val_loss: 0.0195
# Epoch 64/100
# 7/7 [==============================] - 1s 114ms/step - loss: 5.4748e-04 - val_loss: 0.0116
# Epoch 65/100
# 7/7 [==============================] - 1s 113ms/step - loss: 5.8216e-04 - val_loss: 0.0133
# Epoch 66/100
# 7/7 [==============================] - 1s 113ms/step - loss: 5.7607e-04 - val_loss: 0.0255
# Epoch 67/100
# 7/7 [==============================] - 1s 117ms/step - loss: 6.0180e-04 - val_loss: 0.0106
# Epoch 68/100
# 7/7 [==============================] - 1s 115ms/step - loss: 5.0721e-04 - val_loss: 0.0147
# Epoch 69/100
# 7/7 [==============================] - 1s 111ms/step - loss: 5.1376e-04 - val_loss: 0.0152
# Epoch 70/100
# 7/7 [==============================] - 1s 120ms/step - loss: 5.3337e-04 - val_loss: 0.0201
# Epoch 71/100
# 7/7 [==============================] - 1s 110ms/step - loss: 5.1624e-04 - val_loss: 0.0199
# Epoch 72/100
# 7/7 [==============================] - 1s 110ms/step - loss: 5.0683e-04 - val_loss: 0.0122
# Epoch 73/100
# 7/7 [==============================] - 1s 112ms/step - loss: 5.0549e-04 - val_loss: 0.0137
# Epoch 74/100
# 7/7 [==============================] - 1s 112ms/step - loss: 5.0688e-04 - val_loss: 0.0257
# Epoch 75/100
# 7/7 [==============================] - 1s 117ms/step - loss: 6.1426e-04 - val_loss: 0.0108
# Epoch 76/100
# 7/7 [==============================] - 1s 114ms/step - loss: 5.9463e-04 - val_loss: 0.0108
# Epoch 77/100
# 7/7 [==============================] - 1s 108ms/step - loss: 5.4565e-04 - val_loss: 0.0157
# Epoch 78/100
# 7/7 [==============================] - 1s 117ms/step - loss: 5.6179e-04 - val_loss: 0.0143
# Epoch 79/100
# 7/7 [==============================] - 1s 112ms/step - loss: 5.1695e-04 - val_loss: 0.0112
# Epoch 80/100
# 7/7 [==============================] - 1s 110ms/step - loss: 4.8624e-04 - val_loss: 0.0174
# Epoch 81/100
# 7/7 [==============================] - 1s 113ms/step - loss: 5.1854e-04 - val_loss: 0.0116
# Epoch 82/100
# 7/7 [==============================] - 1s 111ms/step - loss: 4.8268e-04 - val_loss: 0.0144
# Epoch 83/100
# 7/7 [==============================] - 1s 111ms/step - loss: 4.9467e-04 - val_loss: 0.0196
# Epoch 84/100
# 7/7 [==============================] - 1s 115ms/step - loss: 5.4220e-04 - val_loss: 0.0216
# Epoch 85/100
# 7/7 [==============================] - 1s 111ms/step - loss: 6.6586e-04 - val_loss: 0.0068
# Epoch 86/100
# 7/7 [==============================] - 1s 110ms/step - loss: 6.7609e-04 - val_loss: 0.0176
# Epoch 87/100
# 7/7 [==============================] - 1s 110ms/step - loss: 5.5339e-04 - val_loss: 0.0119
# Epoch 88/100
# 7/7 [==============================] - 1s 110ms/step - loss: 4.7964e-04 - val_loss: 0.0149
# Epoch 89/100
# 7/7 [==============================] - 1s 116ms/step - loss: 4.7505e-04 - val_loss: 0.0148
# Epoch 90/100
# 7/7 [==============================] - 1s 112ms/step - loss: 4.8151e-04 - val_loss: 0.0127
# Epoch 91/100
# 7/7 [==============================] - 1s 114ms/step - loss: 4.7814e-04 - val_loss: 0.0152
# Epoch 92/100
# 7/7 [==============================] - 1s 117ms/step - loss: 4.7339e-04 - val_loss: 0.0164
# Epoch 93/100
# 7/7 [==============================] - 1s 107ms/step - loss: 4.6375e-04 - val_loss: 0.0158
# Epoch 94/100
# 7/7 [==============================] - 1s 109ms/step - loss: 4.7017e-04 - val_loss: 0.0130
# Epoch 95/100
# 7/7 [==============================] - 1s 119ms/step - loss: 4.4952e-04 - val_loss: 0.0196
# Epoch 96/100
# 7/7 [==============================] - 1s 113ms/step - loss: 5.9143e-04 - val_loss: 0.0182
# Epoch 97/100
# 7/7 [==============================] - 1s 107ms/step - loss: 4.7964e-04 - val_loss: 0.0165
# Epoch 98/100
# 7/7 [==============================] - 1s 111ms/step - loss: 4.6902e-04 - val_loss: 0.0123
# Epoch 99/100
# 7/7 [==============================] - 1s 112ms/step - loss: 4.7704e-04 - val_loss: 0.0120
# Epoch 100/100
# 7/7 [==============================] - 1s 110ms/step - loss: 5.0353e-04 - val_loss: 0.0173

# %% [markdown]
# ### Make Predictions

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %% [markdown]
# ### Visualize Results

# %%
look_back=time_step
trainPredictPlot=np.empty_like(data)
trainPredictPlot[:,:]=np.nan
trainPredictPlot[look_back:len(train_predict)+look_back,:] = train_predict

testPredictPlot=np.empty_like(data)
testPredictPlot[:,:] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(data)-1,:] = test_predict

plt.figure(figsize=(12,8))
plt.plot(scaler.inverse_transform(data))
plt.plot(testPredictPlot)
plt.plot(trainPredictPlot)
plt.legend(['Actual Data','Test Predict','Train Predict'])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,8))
plt.plot(scaler.inverse_transform(data)[len(train_predict)+(look_back*2)+1:len(data)-1])
plt.plot(test_predict)
plt.legend(['Actual Data','Test Predict'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Evaluation

# %%
from sklearn.metrics import mean_squared_error
test_predict=model.predict(X_test)
print('MSE:',mean_squared_error(y_test, test_predict))
# Out:
# MSE: 0.01732310737496416

# %%
print('Volatility:',np.log(df/df.shift()).std()*252**0.5)
# Out:
# Volatility: 0.8524482184431009

# %%
print('Time taken for training in seconds:',end-start)
# Out:
# Time taken for training in seconds: 82.36412692070007
