# %% [markdown]
# ### Imports

# %%
import pandas as pd
from pandas_datareader import data
from datetime import datetime
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ### Obtain and Prepare Data

# %%
start = datetime.strptime('2020-01-02','%Y-%m-%d')
end = datetime.strptime('2022-02-28','%Y-%m-%d')

df = data.DataReader('GME',start=start, end=end, data_source='yahoo')
df = df[:1500]['Close']

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
data = scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
training_size=int(len(data)*0.65)
test_size=len(data)-training_size
train_data,test_data=data[0:training_size,:],data[training_size:len(data),:]

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i+time_step,0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1],1)

# %% [markdown]
# ### Build and Train LSTM

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential() 
model.add(LSTM(50,return_sequences=True,input_shape=(time_step,1))) 
model.add(LSTM(50,return_sequences=True)) 
model.add(LSTM(50)) 
model.add(Dense(1)) 
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
start= time.time()
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)
end=time.time()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 5s 373ms/step - loss: 0.0456 - val_loss: 0.0084
# Epoch 2/100
# 4/4 [==============================] - 0s 122ms/step - loss: 0.0235 - val_loss: 0.0216
# Epoch 3/100
# 4/4 [==============================] - 0s 125ms/step - loss: 0.0189 - val_loss: 0.0102
# Epoch 4/100
# 4/4 [==============================] - 0s 132ms/step - loss: 0.0187 - val_loss: 0.0051
# Epoch 5/100
# 4/4 [==============================] - 0s 122ms/step - loss: 0.0157 - val_loss: 0.0158
# Epoch 6/100
# 4/4 [==============================] - 0s 121ms/step - loss: 0.0161 - val_loss: 0.0136
# Epoch 7/100
# 4/4 [==============================] - 0s 127ms/step - loss: 0.0154 - val_loss: 0.0050
# Epoch 8/100
# 4/4 [==============================] - 0s 124ms/step - loss: 0.0155 - val_loss: 0.0052
# Epoch 9/100
# 4/4 [==============================] - 0s 124ms/step - loss: 0.0149 - val_loss: 0.0098
# Epoch 10/100
# 4/4 [==============================] - 0s 121ms/step - loss: 0.0150 - val_loss: 0.0082
# Epoch 11/100
# 4/4 [==============================] - 0s 126ms/step - loss: 0.0148 - val_loss: 0.0051
# Epoch 12/100
# 4/4 [==============================] - 0s 125ms/step - loss: 0.0143 - val_loss: 0.0066
# Epoch 13/100
# 4/4 [==============================] - 0s 124ms/step - loss: 0.0138 - val_loss: 0.0108
# Epoch 14/100
# 4/4 [==============================] - 1s 133ms/step - loss: 0.0136 - val_loss: 0.0078
# Epoch 15/100
# 4/4 [==============================] - 0s 122ms/step - loss: 0.0133 - val_loss: 0.0063
# Epoch 16/100
# 4/4 [==============================] - 0s 123ms/step - loss: 0.0126 - val_loss: 0.0091
# Epoch 17/100
# 4/4 [==============================] - 0s 128ms/step - loss: 0.0124 - val_loss: 0.0103
# Epoch 18/100
# 4/4 [==============================] - 0s 126ms/step - loss: 0.0117 - val_loss: 0.0090
# Epoch 19/100
# 4/4 [==============================] - 0s 124ms/step - loss: 0.0112 - val_loss: 0.0119
# Epoch 20/100
# 4/4 [==============================] - 0s 123ms/step - loss: 0.0109 - val_loss: 0.0122
# Epoch 21/100
# 4/4 [==============================] - 0s 125ms/step - loss: 0.0107 - val_loss: 0.0228
# Epoch 22/100
# 4/4 [==============================] - 0s 123ms/step - loss: 0.0104 - val_loss: 0.0144
# Epoch 23/100
# 4/4 [==============================] - 0s 122ms/step - loss: 0.0097 - val_loss: 0.0197
# Epoch 24/100
# 4/4 [==============================] - 0s 127ms/step - loss: 0.0099 - val_loss: 0.0180
# Epoch 25/100
# 4/4 [==============================] - 0s 126ms/step - loss: 0.0093 - val_loss: 0.0181
# Epoch 26/100
# 4/4 [==============================] - 0s 125ms/step - loss: 0.0092 - val_loss: 0.0203
# Epoch 27/100
# 4/4 [==============================] - 0s 131ms/step - loss: 0.0090 - val_loss: 0.0188
# Epoch 28/100
# 4/4 [==============================] - 0s 122ms/step - loss: 0.0092 - val_loss: 0.0203
# Epoch 29/100
# 4/4 [==============================] - 0s 126ms/step - loss: 0.0089 - val_loss: 0.0182
# Epoch 30/100
# 4/4 [==============================] - 0s 127ms/step - loss: 0.0083 - val_loss: 0.0186
# Epoch 31/100
# 4/4 [==============================] - 0s 124ms/step - loss: 0.0086 - val_loss: 0.0185
# Epoch 32/100
# 4/4 [==============================] - 0s 129ms/step - loss: 0.0083 - val_loss: 0.0162
# Epoch 33/100
# 4/4 [==============================] - 0s 122ms/step - loss: 0.0081 - val_loss: 0.0217
# Epoch 34/100
# 4/4 [==============================] - 0s 129ms/step - loss: 0.0083 - val_loss: 0.0166
# Epoch 35/100
# 4/4 [==============================] - 0s 125ms/step - loss: 0.0080 - val_loss: 0.0150
# Epoch 36/100
# 4/4 [==============================] - 0s 122ms/step - loss: 0.0082 - val_loss: 0.0176
# Epoch 37/100
# 4/4 [==============================] - 1s 135ms/step - loss: 0.0079 - val_loss: 0.0163
# Epoch 38/100
# 4/4 [==============================] - 1s 141ms/step - loss: 0.0077 - val_loss: 0.0162
# Epoch 39/100
# 4/4 [==============================] - 1s 133ms/step - loss: 0.0078 - val_loss: 0.0167
# Epoch 40/100
# 4/4 [==============================] - 0s 128ms/step - loss: 0.0079 - val_loss: 0.0160
# Epoch 41/100
# 4/4 [==============================] - 1s 143ms/step - loss: 0.0076 - val_loss: 0.0154
# Epoch 42/100
# 4/4 [==============================] - 1s 133ms/step - loss: 0.0075 - val_loss: 0.0142
# Epoch 43/100
# 4/4 [==============================] - 1s 133ms/step - loss: 0.0078 - val_loss: 0.0188
# Epoch 44/100
# 4/4 [==============================] - 1s 144ms/step - loss: 0.0077 - val_loss: 0.0142
# Epoch 45/100
# 4/4 [==============================] - 1s 134ms/step - loss: 0.0076 - val_loss: 0.0182
# Epoch 46/100
# 4/4 [==============================] - 1s 132ms/step - loss: 0.0075 - val_loss: 0.0150
# Epoch 47/100
# 4/4 [==============================] - 1s 131ms/step - loss: 0.0076 - val_loss: 0.0147
# Epoch 48/100
# 4/4 [==============================] - 1s 133ms/step - loss: 0.0078 - val_loss: 0.0185
# Epoch 49/100
# 4/4 [==============================] - 1s 136ms/step - loss: 0.0076 - val_loss: 0.0137
# Epoch 50/100
# 4/4 [==============================] - 1s 134ms/step - loss: 0.0075 - val_loss: 0.0173
# Epoch 51/100
# 4/4 [==============================] - 0s 130ms/step - loss: 0.0074 - val_loss: 0.0141
# Epoch 52/100
# 4/4 [==============================] - 1s 134ms/step - loss: 0.0075 - val_loss: 0.0201
# Epoch 53/100
# 4/4 [==============================] - 1s 133ms/step - loss: 0.0077 - val_loss: 0.0135
# Epoch 54/100
# 4/4 [==============================] - 1s 136ms/step - loss: 0.0076 - val_loss: 0.0171
# Epoch 55/100
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0074 - val_loss: 0.0149
# Epoch 56/100
# 4/4 [==============================] - 1s 135ms/step - loss: 0.0072 - val_loss: 0.0129
# Epoch 57/100
# 4/4 [==============================] - 1s 135ms/step - loss: 0.0070 - val_loss: 0.0186
# Epoch 58/100
# 4/4 [==============================] - 0s 130ms/step - loss: 0.0072 - val_loss: 0.0129
# Epoch 59/100
# 4/4 [==============================] - 1s 138ms/step - loss: 0.0071 - val_loss: 0.0182
# Epoch 60/100
# 4/4 [==============================] - 1s 131ms/step - loss: 0.0069 - val_loss: 0.0124
# Epoch 61/100
# 4/4 [==============================] - 1s 132ms/step - loss: 0.0071 - val_loss: 0.0142
# Epoch 62/100
# 4/4 [==============================] - 1s 141ms/step - loss: 0.0067 - val_loss: 0.0126
# Epoch 63/100
# 4/4 [==============================] - 1s 173ms/step - loss: 0.0066 - val_loss: 0.0142
# Epoch 64/100
# 4/4 [==============================] - 1s 131ms/step - loss: 0.0067 - val_loss: 0.0122
# Epoch 65/100
# 4/4 [==============================] - 1s 136ms/step - loss: 0.0065 - val_loss: 0.0140
# Epoch 66/100
# 4/4 [==============================] - 1s 154ms/step - loss: 0.0065 - val_loss: 0.0123
# Epoch 67/100
# 4/4 [==============================] - 1s 157ms/step - loss: 0.0064 - val_loss: 0.0125
# Epoch 68/100
# 4/4 [==============================] - 1s 156ms/step - loss: 0.0064 - val_loss: 0.0166
# Epoch 69/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.0063 - val_loss: 0.0117
# Epoch 70/100
# 4/4 [==============================] - 1s 158ms/step - loss: 0.0061 - val_loss: 0.0123
# Epoch 71/100
# 4/4 [==============================] - 1s 164ms/step - loss: 0.0059 - val_loss: 0.0132
# Epoch 72/100
# 4/4 [==============================] - 1s 176ms/step - loss: 0.0057 - val_loss: 0.0110
# Epoch 73/100
# 4/4 [==============================] - 1s 169ms/step - loss: 0.0056 - val_loss: 0.0121
# Epoch 74/100
# 4/4 [==============================] - 1s 168ms/step - loss: 0.0055 - val_loss: 0.0114
# Epoch 75/100
# 4/4 [==============================] - 1s 190ms/step - loss: 0.0055 - val_loss: 0.0101
# Epoch 76/100
# 4/4 [==============================] - 1s 192ms/step - loss: 0.0053 - val_loss: 0.0124
# Epoch 77/100
# 4/4 [==============================] - 1s 174ms/step - loss: 0.0052 - val_loss: 0.0095
# Epoch 78/100
# 4/4 [==============================] - 1s 180ms/step - loss: 0.0052 - val_loss: 0.0113
# Epoch 79/100
# 4/4 [==============================] - 1s 224ms/step - loss: 0.0048 - val_loss: 0.0091
# Epoch 80/100
# 4/4 [==============================] - 1s 198ms/step - loss: 0.0047 - val_loss: 0.0088
# Epoch 81/100
# 4/4 [==============================] - 1s 178ms/step - loss: 0.0047 - val_loss: 0.0094
# Epoch 82/100
# 4/4 [==============================] - 1s 181ms/step - loss: 0.0047 - val_loss: 0.0100
# Epoch 83/100
# 4/4 [==============================] - 1s 174ms/step - loss: 0.0047 - val_loss: 0.0091
# Epoch 84/100
# 4/4 [==============================] - 1s 169ms/step - loss: 0.0046 - val_loss: 0.0118
# Epoch 85/100
# 4/4 [==============================] - 1s 176ms/step - loss: 0.0044 - val_loss: 0.0105
# Epoch 86/100
# 4/4 [==============================] - 1s 173ms/step - loss: 0.0042 - val_loss: 0.0107
# Epoch 87/100
# 4/4 [==============================] - 1s 174ms/step - loss: 0.0042 - val_loss: 0.0089
# Epoch 88/100
# 4/4 [==============================] - 1s 184ms/step - loss: 0.0039 - val_loss: 0.0092
# Epoch 89/100
# 4/4 [==============================] - 1s 180ms/step - loss: 0.0040 - val_loss: 0.0114
# Epoch 90/100
# 4/4 [==============================] - 1s 178ms/step - loss: 0.0039 - val_loss: 0.0089
# Epoch 91/100
# 4/4 [==============================] - 1s 182ms/step - loss: 0.0037 - val_loss: 0.0109
# Epoch 92/100
# 4/4 [==============================] - 1s 180ms/step - loss: 0.0036 - val_loss: 0.0102
# Epoch 93/100
# 4/4 [==============================] - 1s 179ms/step - loss: 0.0035 - val_loss: 0.0108
# Epoch 94/100
# 4/4 [==============================] - 1s 185ms/step - loss: 0.0035 - val_loss: 0.0121
# Epoch 95/100
# 4/4 [==============================] - 1s 177ms/step - loss: 0.0034 - val_loss: 0.0130
# Epoch 96/100
# 4/4 [==============================] - 1s 181ms/step - loss: 0.0031 - val_loss: 0.0123
# Epoch 97/100
# 4/4 [==============================] - 1s 179ms/step - loss: 0.0032 - val_loss: 0.0142
# Epoch 98/100
# 4/4 [==============================] - 1s 178ms/step - loss: 0.0035 - val_loss: 0.0133
# Epoch 99/100
# 4/4 [==============================] - 1s 172ms/step - loss: 0.0031 - val_loss: 0.0114
# Epoch 100/100
# 4/4 [==============================] - 1s 178ms/step - loss: 0.0030 - val_loss: 0.0137

# %% [markdown]
# ### Make Predictions

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %% [markdown]
# ### Visualize Results

# %%
look_back=time_step
trainPredictPlot=np.empty_like(data)
trainPredictPlot[:,:]=np.nan
trainPredictPlot[look_back:len(train_predict)+look_back,:] = train_predict

testPredictPlot=np.empty_like(data)
testPredictPlot[:,:] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(data)-1,:] = test_predict

plt.figure(figsize=(12,8))
plt.plot(scaler.inverse_transform(data))
plt.plot(testPredictPlot)
plt.plot(trainPredictPlot)
plt.legend(['Actual Data','Test Predict','Train Predict'])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,8))
plt.plot(scaler.inverse_transform(data)[len(train_predict)+(look_back*2)+1:len(data)-1])
plt.plot(test_predict)
plt.legend(['Actual Data','Test Predict'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Evaluation

# %%
from sklearn.metrics import mean_squared_error
test_predict=model.predict(X_test)
print('MSE:',mean_squared_error(y_test, test_predict))
# Out:
# MSE: 0.01371367312563377

# %%
print('Coefficient of Variation:',df.std()/df.mean())
# Out:
# Coefficient of Variation: 0.9746932797917992

# %%
print('Time taken for training in seconds:',end-start)
# Out:
# Time taken for training in seconds: 59.82143783569336
