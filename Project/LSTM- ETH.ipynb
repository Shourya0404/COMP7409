# %% [markdown]
# ### Imports

# %%
import pandas as pd
from pandas_datareader import data
from datetime import datetime
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ### Obtain and Prepare Data

# %%
start = datetime.strptime('2020-01-02','%Y-%m-%d')
end = datetime.strptime('2022-02-28','%Y-%m-%d')

df = data.DataReader('ETH-USD',start=start, end=end, data_source='yahoo')
df = df[:1500]['Close']

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
data = scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
training_size=int(len(data)*0.65)
test_size=len(data)-training_size
train_data,test_data=data[0:training_size,:],data[training_size:len(data),:]

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i+time_step,0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1],1)

# %% [markdown]
# ### Build and Train LSTM

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential() 
model.add(LSTM(50,return_sequences=True,input_shape=(time_step,1))) 
model.add(LSTM(50,return_sequences=True)) 
model.add(LSTM(50)) 
model.add(Dense(1)) 
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
start= time.time()
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)
end=time.time()
# Out:
# Epoch 1/100
# 7/7 [==============================] - 11s 374ms/step - loss: 0.0453 - val_loss: 0.0095
# Epoch 2/100
# 7/7 [==============================] - 1s 153ms/step - loss: 0.0092 - val_loss: 0.0201
# Epoch 3/100
# 7/7 [==============================] - 1s 160ms/step - loss: 0.0050 - val_loss: 0.1356
# Epoch 4/100
# 7/7 [==============================] - 1s 193ms/step - loss: 0.0042 - val_loss: 0.0083
# Epoch 5/100
# 7/7 [==============================] - 1s 162ms/step - loss: 0.0035 - val_loss: 0.0135
# Epoch 6/100
# 7/7 [==============================] - 1s 153ms/step - loss: 0.0037 - val_loss: 0.0071
# Epoch 7/100
# 7/7 [==============================] - 1s 182ms/step - loss: 0.0026 - val_loss: 0.0134
# Epoch 8/100
# 7/7 [==============================] - 1s 161ms/step - loss: 0.0027 - val_loss: 0.0072
# Epoch 9/100
# 7/7 [==============================] - 1s 166ms/step - loss: 0.0025 - val_loss: 0.0077
# Epoch 10/100
# 7/7 [==============================] - 1s 163ms/step - loss: 0.0026 - val_loss: 0.0078
# Epoch 11/100
# 7/7 [==============================] - 1s 145ms/step - loss: 0.0024 - val_loss: 0.0073
# Epoch 12/100
# 7/7 [==============================] - 1s 163ms/step - loss: 0.0024 - val_loss: 0.0083
# Epoch 13/100
# 7/7 [==============================] - 1s 171ms/step - loss: 0.0024 - val_loss: 0.0075
# Epoch 14/100
# 7/7 [==============================] - 1s 153ms/step - loss: 0.0026 - val_loss: 0.0082
# Epoch 15/100
# 7/7 [==============================] - 1s 144ms/step - loss: 0.0023 - val_loss: 0.0076
# Epoch 16/100
# 7/7 [==============================] - 1s 146ms/step - loss: 0.0023 - val_loss: 0.0104
# Epoch 17/100
# 7/7 [==============================] - 1s 151ms/step - loss: 0.0025 - val_loss: 0.0075
# Epoch 18/100
# 7/7 [==============================] - 1s 149ms/step - loss: 0.0024 - val_loss: 0.0111
# Epoch 19/100
# 7/7 [==============================] - 1s 147ms/step - loss: 0.0025 - val_loss: 0.0069
# Epoch 20/100
# 7/7 [==============================] - 1s 147ms/step - loss: 0.0024 - val_loss: 0.0149
# Epoch 21/100
# 7/7 [==============================] - 1s 151ms/step - loss: 0.0024 - val_loss: 0.0070
# Epoch 22/100
# 7/7 [==============================] - 1s 143ms/step - loss: 0.0022 - val_loss: 0.0109
# Epoch 23/100
# 7/7 [==============================] - 1s 148ms/step - loss: 0.0022 - val_loss: 0.0093
# Epoch 24/100
# 7/7 [==============================] - 1s 152ms/step - loss: 0.0020 - val_loss: 0.0113
# Epoch 25/100
# 7/7 [==============================] - 1s 151ms/step - loss: 0.0019 - val_loss: 0.0079
# Epoch 26/100
# 7/7 [==============================] - 1s 148ms/step - loss: 0.0019 - val_loss: 0.0126
# Epoch 27/100
# 7/7 [==============================] - 1s 147ms/step - loss: 0.0019 - val_loss: 0.0144
# Epoch 28/100
# 7/7 [==============================] - 1s 148ms/step - loss: 0.0020 - val_loss: 0.0205
# Epoch 29/100
# 7/7 [==============================] - 1s 146ms/step - loss: 0.0018 - val_loss: 0.0165
# Epoch 30/100
# 7/7 [==============================] - 1s 151ms/step - loss: 0.0018 - val_loss: 0.0111
# Epoch 31/100
# 7/7 [==============================] - 1s 152ms/step - loss: 0.0019 - val_loss: 0.0220
# Epoch 32/100
# 7/7 [==============================] - 1s 148ms/step - loss: 0.0016 - val_loss: 0.0097
# Epoch 33/100
# 7/7 [==============================] - 1s 152ms/step - loss: 0.0016 - val_loss: 0.0201
# Epoch 34/100
# 7/7 [==============================] - 1s 148ms/step - loss: 0.0013 - val_loss: 0.0114
# Epoch 35/100
# 7/7 [==============================] - 1s 117ms/step - loss: 0.0012 - val_loss: 0.0112
# Epoch 36/100
# 7/7 [==============================] - 1s 125ms/step - loss: 0.0011 - val_loss: 0.0085
# Epoch 37/100
# 7/7 [==============================] - 1s 119ms/step - loss: 0.0010 - val_loss: 0.0086
# Epoch 38/100
# 7/7 [==============================] - 1s 117ms/step - loss: 9.7848e-04 - val_loss: 0.0074
# Epoch 39/100
# 7/7 [==============================] - 1s 116ms/step - loss: 8.9185e-04 - val_loss: 0.0067
# Epoch 40/100
# 7/7 [==============================] - 1s 116ms/step - loss: 9.1332e-04 - val_loss: 0.0068
# Epoch 41/100
# 7/7 [==============================] - 1s 112ms/step - loss: 7.8800e-04 - val_loss: 0.0122
# Epoch 42/100
# 7/7 [==============================] - 1s 111ms/step - loss: 7.1965e-04 - val_loss: 0.0104
# Epoch 43/100
# 7/7 [==============================] - 1s 110ms/step - loss: 6.1013e-04 - val_loss: 0.0118
# Epoch 44/100
# 7/7 [==============================] - 1s 111ms/step - loss: 5.9014e-04 - val_loss: 0.0176
# Epoch 45/100
# 7/7 [==============================] - 1s 109ms/step - loss: 5.7955e-04 - val_loss: 0.0170
# Epoch 46/100
# 7/7 [==============================] - 1s 116ms/step - loss: 5.7743e-04 - val_loss: 0.0139
# Epoch 47/100
# 7/7 [==============================] - 1s 117ms/step - loss: 5.8655e-04 - val_loss: 0.0170
# Epoch 48/100
# 7/7 [==============================] - 1s 118ms/step - loss: 6.2127e-04 - val_loss: 0.0149
# Epoch 49/100
# 7/7 [==============================] - 1s 119ms/step - loss: 6.5286e-04 - val_loss: 0.0193
# Epoch 50/100
# 7/7 [==============================] - 1s 117ms/step - loss: 5.8078e-04 - val_loss: 0.0198
# Epoch 51/100
# 7/7 [==============================] - 1s 111ms/step - loss: 5.7118e-04 - val_loss: 0.0173
# Epoch 52/100
# 7/7 [==============================] - 1s 110ms/step - loss: 6.1055e-04 - val_loss: 0.0215
# Epoch 53/100
# 7/7 [==============================] - 1s 112ms/step - loss: 7.2972e-04 - val_loss: 0.0183
# Epoch 54/100
# 7/7 [==============================] - 1s 109ms/step - loss: 6.3749e-04 - val_loss: 0.0156
# Epoch 55/100
# 7/7 [==============================] - 1s 110ms/step - loss: 5.7645e-04 - val_loss: 0.0133
# Epoch 56/100
# 7/7 [==============================] - 1s 110ms/step - loss: 6.1906e-04 - val_loss: 0.0176
# Epoch 57/100
# 7/7 [==============================] - 1s 110ms/step - loss: 5.6408e-04 - val_loss: 0.0240
# Epoch 58/100
# 7/7 [==============================] - 1s 117ms/step - loss: 5.8424e-04 - val_loss: 0.0149
# Epoch 59/100
# 7/7 [==============================] - 1s 109ms/step - loss: 6.3584e-04 - val_loss: 0.0117
# Epoch 60/100
# 7/7 [==============================] - 1s 110ms/step - loss: 6.0521e-04 - val_loss: 0.0158
# Epoch 61/100
# 7/7 [==============================] - 1s 109ms/step - loss: 5.8761e-04 - val_loss: 0.0203
# Epoch 62/100
# 7/7 [==============================] - 1s 110ms/step - loss: 5.7326e-04 - val_loss: 0.0175
# Epoch 63/100
# 7/7 [==============================] - 1s 110ms/step - loss: 5.6675e-04 - val_loss: 0.0148
# Epoch 64/100
# 7/7 [==============================] - 1s 113ms/step - loss: 5.3066e-04 - val_loss: 0.0160
# Epoch 65/100
# 7/7 [==============================] - 1s 108ms/step - loss: 5.2125e-04 - val_loss: 0.0246
# Epoch 66/100
# 7/7 [==============================] - 1s 110ms/step - loss: 6.0801e-04 - val_loss: 0.0195
# Epoch 67/100
# 7/7 [==============================] - 1s 112ms/step - loss: 5.9091e-04 - val_loss: 0.0086
# Epoch 68/100
# 7/7 [==============================] - 1s 110ms/step - loss: 9.1530e-04 - val_loss: 0.0145
# Epoch 69/100
# 7/7 [==============================] - 1s 118ms/step - loss: 4.9922e-04 - val_loss: 0.0162
# Epoch 70/100
# 7/7 [==============================] - 1s 111ms/step - loss: 5.5521e-04 - val_loss: 0.0221
# Epoch 71/100
# 7/7 [==============================] - 1s 118ms/step - loss: 5.4396e-04 - val_loss: 0.0165
# Epoch 72/100
# 7/7 [==============================] - 1s 118ms/step - loss: 5.7743e-04 - val_loss: 0.0105
# Epoch 73/100
# 7/7 [==============================] - 1s 112ms/step - loss: 5.3890e-04 - val_loss: 0.0148
# Epoch 74/100
# 7/7 [==============================] - 1s 115ms/step - loss: 5.0348e-04 - val_loss: 0.0162
# Epoch 75/100
# 7/7 [==============================] - 1s 115ms/step - loss: 5.2043e-04 - val_loss: 0.0157
# Epoch 76/100
# 7/7 [==============================] - 1s 113ms/step - loss: 5.1157e-04 - val_loss: 0.0158
# Epoch 77/100
# 7/7 [==============================] - 1s 114ms/step - loss: 4.8944e-04 - val_loss: 0.0165
# Epoch 78/100
# 7/7 [==============================] - 1s 114ms/step - loss: 4.9807e-04 - val_loss: 0.0174
# Epoch 79/100
# 7/7 [==============================] - 1s 114ms/step - loss: 5.1145e-04 - val_loss: 0.0126
# Epoch 80/100
# 7/7 [==============================] - 1s 116ms/step - loss: 4.8252e-04 - val_loss: 0.0157
# Epoch 81/100
# 7/7 [==============================] - 1s 121ms/step - loss: 5.1550e-04 - val_loss: 0.0164
# Epoch 82/100
# 7/7 [==============================] - 1s 116ms/step - loss: 5.7916e-04 - val_loss: 0.0138
# Epoch 83/100
# 7/7 [==============================] - 1s 110ms/step - loss: 8.9516e-04 - val_loss: 0.0234
# Epoch 84/100
# 7/7 [==============================] - 1s 116ms/step - loss: 8.4120e-04 - val_loss: 0.0134
# Epoch 85/100
# 7/7 [==============================] - 1s 116ms/step - loss: 6.5789e-04 - val_loss: 0.0095
# Epoch 86/100
# 7/7 [==============================] - 1s 117ms/step - loss: 7.2936e-04 - val_loss: 0.0161
# Epoch 87/100
# 7/7 [==============================] - 1s 115ms/step - loss: 6.3104e-04 - val_loss: 0.0161
# Epoch 88/100
# 7/7 [==============================] - 1s 117ms/step - loss: 5.6277e-04 - val_loss: 0.0131
# Epoch 89/100
# 7/7 [==============================] - 1s 117ms/step - loss: 4.8793e-04 - val_loss: 0.0138
# Epoch 90/100
# 7/7 [==============================] - 1s 120ms/step - loss: 4.8027e-04 - val_loss: 0.0137
# Epoch 91/100
# 7/7 [==============================] - 1s 118ms/step - loss: 5.0695e-04 - val_loss: 0.0132
# Epoch 92/100
# 7/7 [==============================] - 1s 117ms/step - loss: 4.9457e-04 - val_loss: 0.0160
# Epoch 93/100
# 7/7 [==============================] - 1s 117ms/step - loss: 4.8291e-04 - val_loss: 0.0174
# Epoch 94/100
# 7/7 [==============================] - 1s 116ms/step - loss: 5.0358e-04 - val_loss: 0.0180
# Epoch 95/100
# 7/7 [==============================] - 1s 117ms/step - loss: 5.1974e-04 - val_loss: 0.0124
# Epoch 96/100
# 7/7 [==============================] - 1s 117ms/step - loss: 5.8643e-04 - val_loss: 0.0184
# Epoch 97/100
# 7/7 [==============================] - 1s 119ms/step - loss: 5.4395e-04 - val_loss: 0.0179
# Epoch 98/100
# 7/7 [==============================] - 1s 117ms/step - loss: 5.1194e-04 - val_loss: 0.0138
# Epoch 99/100
# 7/7 [==============================] - 1s 117ms/step - loss: 5.3509e-04 - val_loss: 0.0189
# Epoch 100/100
# 7/7 [==============================] - 1s 117ms/step - loss: 5.2024e-04 - val_loss: 0.0200

# %% [markdown]
# ### Make Predictions

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %% [markdown]
# ### Visualize Results

# %%
look_back=time_step
trainPredictPlot=np.empty_like(data)
trainPredictPlot[:,:]=np.nan
trainPredictPlot[look_back:len(train_predict)+look_back,:] = train_predict

testPredictPlot=np.empty_like(data)
testPredictPlot[:,:] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(data)-1,:] = test_predict

plt.figure(figsize=(12,8))
plt.plot(scaler.inverse_transform(data))
plt.plot(testPredictPlot)
plt.plot(trainPredictPlot)
plt.legend(['Actual Data','Test Predict','Train Predict'])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,8))
plt.plot(scaler.inverse_transform(data)[len(train_predict)+(look_back*2)+1:len(data)-1])
plt.plot(test_predict)
plt.legend(['Actual Data','Test Predict'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Evaluation

# %%
from sklearn.metrics import mean_squared_error
test_predict=model.predict(X_test)
print('MSE:',mean_squared_error(y_test, test_predict))
# Out:
# MSE: 0.019951843597639705

# %%
print('Coefficient of Variation:',df.std()/df.mean())
# Out:
# Coefficient of Variation: 0.8705347249148911

# %%
print('Time taken for training in seconds:',end-start)
# Out:
# Time taken for training in seconds: 98.15780138969421
